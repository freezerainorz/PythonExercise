# %%
import pandas as pd
import requests

# %%
plant_data=requests.get('https://data.taipei/opendata/datalist/apiAccess?scope=resourceAquire&rid=f18de02f-b6c9-47c0-8cda-50efad621c14')

# %%
plant_data.json()
# Out:
# {'result': {'limit': 1000,
#   'offset': 0,
#   'count': 110,
#   'sort': '',
#   'results': [{'F_Name_Latin': 'Lagerstroemia subcostata',
#     'F_pdf02_ALT': '',
#     'F_Location': '臺灣動物區；蟲蟲探索谷；熱帶雨林區；鳥園；兩棲爬蟲動物館',
#     'F_pdf01_ALT': '',
#     'F_Summary': '',
#     'F_Pic01_URL': 'http://www.zoo.gov.tw/iTAP/04_Plant/Lythraceae/subcostata/subcostata_1.jpg',
#     'F_pdf02_URL': '',
#     'F_Pic02_URL': '',
#     'F_Keywords': '',
#     'F_Code': '',
#     'F_Geo': 'MULTIPOINT ((121.5804577 24.9979216),  (121.5805328 24.9959671),  (121.5836763 24.9957094),  (121.5894029 24.9951126),  (121.5899205 24.9945669))',
#     'F_Pic03_URL': '',
#     'F_Voice01_ALT': '',
#     'F_AlsoKnown': '苞飯花、拘那花、小果紫薇、南紫薇、猴不爬、怕癢樹、南紫薇、九荊、馬鈴花、蚊仔花',
#     'F_Voice02_ALT': '',
#     'F_Name_Ch': '九芎',
#     'F_Pic04_ALT': '',
#     'F_Name_En': 'Subcostate Crape Myrtle',
#     'F_Brief': '分布於中低海拔森林及長江以南的地區，為台灣的原生樹種。主要生長在潮濕的崩塌地，有吸水保持土壤之特性，所以是良好的水土保持樹種。',
#     'F_Pic04_URL': '',
#     'F_Voice01_URL': '',
# ...

# %%
pd.DataFrame(plant_data.json()['result']['results'])
# Out:
#                         F_Name_Latin F_pdf02_ALT  \
# 0           Lagerstroemia subcostata
# 1             Hygrophila pogonocalyx
# 2             Lagerstroemia speciosa
# 3                    Deutzia pulchra
# 4                   Heliconia bihai
# ..                               ...         ...
# 105      Swieteniamahagoni(L.) Jacq.
# 106        Bischofia javanica Blume.
# 107       Chorisia speciosa St. Hil.
# 108  Artocarpusincisus(Thunb.) L. f.
# 109          Elaeocarpus serratus L.
#
#                          F_Location F_pdf01_ALT F_Summary  \
# 0      臺灣動物區；蟲蟲探索谷；熱帶雨林區；鳥園；兩棲爬蟲動物館
# 1                蟲蟲探索谷；水生植物園；白手長臂猿島
# 2    臺灣動物區；蟲蟲探索谷；兒童動物區；熱帶雨林區；白手長臂猿島
# 3                       臺灣動物區；熱帶雨林區
# 4                                鳥園
# ..                              ...         ...       ...
# 105                            穿山甲館
# 106                            穿山甲館
# 107                            穿山甲館
# 108                            穿山甲館
# 109                            穿山甲館
# ...
